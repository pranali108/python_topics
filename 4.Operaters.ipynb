# %%
# Logical Operater

# %%
# 1. AND Operater
True & True
# Out:
# True

# %%
True & False
# Out:
# False

# %%
False & True
# Out:
# False

# %%
False & False
# Out:
# False

# %%
# 2.OR Operater
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
True + True   # true = 1
# Out:
# 2

# %%
True - False
# Out:
# 1

# %%
# Comparison Operater
5 > 1
# Out:
# True

# %%
3 < 10
# Out:
# True

# %%
4 >= 4
# Out:
# True

# %%
5 == 5
# Out:
# True

# %%
'Hello' == 'hello'
# Out:
# False

# %%
a = 5

# %%
5 == 5
# Out:
# True

# %%
a == 5
# Out:
# True

# %%
'Hi' != 'By'
# Out:
# True

# %%
5 != 5
# Out:
# False

# %%
age = 30

# %%
print('My age is', age)
# Out:
# My age is 50

# %%
print(f'My age is {age} and i am very good person')
# Out:
# My age is 50 and i am very good person

# %%
name = 'xyz'

# %%
print(f'My name is {name} and my age is {age}')
# Out:
# My name is xyz and my age is 50

# %%
print('My name is {name} and my age is {age}')
# Out:
# My name is {name} and my age is {age}

# %%
name = input('Enter your name')
print(f'My name is {name}')
# Out:
# Enter your name Priya
# My name is Priya

# %%
type(name)
# Out:
# str

# %%
age = input('Enter your age')
print(f'Your age is {age}')
# Out:
# Enter your age 30
# Your age is 30

# %%
age = int(input('Enter your age'))
print(f'Your age is {age}')
# Out:
# Enter your age 30
# Your age is 30

# %%
student_name = input('Enter student name')
marks = float(input('Enter your marks'))
print(f'Student name is {student_name} and marks are {marks} ')
# Out:
# Enter student name Sham
# Enter your marks 80.0
# Student name is Sham and marks are 80.0

# %% [markdown]
# # Data Structures

# %%
# 1. List

# %%
a = [1,2,3,4,5]
a
# Out:
# [1, 2, 3, 4, 5]

# %%
mix = [1,14.5, 10+5j, True, 'Hello']
mix
# Out:
# [1, 14.5, (10+5j), True, 'Hello']

# %%
type(mix)
# Out:
# list

# %%
names = ['Sonu', 'Priya', 'Anu', 'Pooja']
names
# Out:
# ['Sonu', 'Priya', 'Anu', 'Pooja']
