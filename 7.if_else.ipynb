# %%
if 1 > 5:
    print(True)
else:
    print(False)
# Out:
# False

# %%
1 > 5
# Out:
# False

# %%
if 10 > 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Fail

# %%
marks = float(input("Enter Your Marks: "))

if marks >= 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Enter Your Marks:  77
# Pass

# %%
marks = float(input('Enter your marks'))

if marks >= 90:
    print('A')
elif marks >=70:
    print('B')
elif marks >= 50:
    print('C')
elif marks >= 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Enter your marks 95
# A

# %%
# course info

# %%
course = input('Enter your course name')

if course == 'python':
    print('Yes we have python course')
elif course == 'java':
    print('We have java courese')
else:
    print(f'We dont have {course} course.')
# Out:
# Enter your course name python
# Yes we have python course

# %%
'JAVA'.lower() #convert into lower case
# Out:
# 'java'

# %%
coupon = input("Enter your coupon code")
total = float(input("Enter your Total bill"))

if coupon == 'DATA50':
    discount = total * 0.5
    print(f'You will get discount of {discount}')
    final_price = print(f'Your final total bill is {total - discount}')
elif coupon == 'DATA70':
    discount = total * 0.7
    print(f'You will get discount of {discount}')
    final_price = print(f'Your final total bill is {total - discount}')
else:
    print('Coupon code is not valid')
    print(f'Your Final Price will be {total}')
# Out:
# Enter your coupon code DATA50
# Enter your Total bill 1000
# You will get discount of 500.0
# Your final total bill is 500.0

# %%
100 * 0.7
# Out:
# 70.0

# %%
# Task - similar codde for course and discount

# %%
course = input("Enter your course")

if course == 'Python':
    course_fee = 12000
    discount = course_fee * 0.3
    print(f'Python course fee is {course_fee}')
    print(f'You will get discount of {discount}')
    final_price = print(f'Your final total fee is {course_fee - discount}')
elif course == 'JAVA':
    course_fee = 25000
    discount = course_fee * 0.2
    print(f'Java course fee is {course_fee}')
    print(f'You will get discount of {discount}')
    final_price = print(f'Your final total fee is {course_fee - discount}')
else:
    print('No Discount available for this course')
    print(f'Your Final Course Fee is {total_fees}')
# Out:
# Enter your course Python
# Python course fee is 12000
# You will get discount of 3600.0
# Your final total fee is 8400.0

# %%
marks = float(input('Enter your marks'))

if marks >= 90 and marks <= 100:
    print('A')
elif marks >= 70 and marks < 90:
    print('B')
elif marks >= 50 and marks < 70: 
    print('C')
elif marks >= 35 and marks < 50: 
    print('Pass')
elif marks >= 0 and marks < 35: 
    print('Fail')
else:
    print('Please write marks between 0-100 range')
# Out:
# Enter your marks 90
# A

# %%
num = int(input('Enter your number'))
if num % 2 == 0:
    print(num , 'is a even number')
elif num % 2 != 0:
    print(num , 'is a odd number')
else:
    print('Please rewrite num')
# Out:
# Enter your number 33
# 33 is a odd number
